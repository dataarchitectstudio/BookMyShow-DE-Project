# %% [markdown]
# ### BookMyShow Data Exploration
#
# Use this notebook to explore the bronze/silver/gold BookMyShow tables produced by the `bookmyshow_etl` pipeline, in your preferred programming language.
#
# **Note**: This notebook is not executed as part of the pipeline.

# %%
# Once bronze/silver/gold transformations have been added and the pipeline has run,
# explore the resulting tables here, e.g.:
#
# display(spark.sql(f"SELECT * FROM {catalog}.{gold_schema}.gold_fact_bookings LIMIT 100"))
